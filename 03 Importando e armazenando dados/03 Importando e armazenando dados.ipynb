# %%
import pandas as pd

# %%
arquivo = "dados/arquivo_csv_virgula.csv"

# %%
colunas = ['Nome', 'Idade', 'Renda', 'Sexo', 'Cidade', 'Estado', 'Nascimento']
funcionarios = pd.read_csv(arquivo, sep= ",", parse_dates=["Data de Nascimento"], encoding="utf-8", thousands=".", decimal=",", dtype={"Renda Mensal": "float", "Idade": "float"})
funcionarios.head()
# Out:
#     Nome Completo  Idade  Renda Mensal       Sexo          Cidade Estado  \
# 0   João da Silva   54.0         227.0   Feminino       São Paulo     SP
# 1  Maria Oliveira   80.0        5147.0  Masculino  Rio de Janeiro     RJ
# 2    Pedro Santos   46.0        8657.0  Masculino  Belo Horizonte     MG
# 3       Ana Costa   30.0        5026.0   Feminino        Salvador     BA
# 4   Lucas Pereira   39.0        4128.0  Masculino        Curitiba     PR
#
#           Data de Nascimento
# 0 1970-06-15 22:19:00.037648
# 1 1944-06-15 10:19:00.037648
# 2 1978-06-15 22:19:00.037648
# 3 1994-06-15 22:19:00.037648
# 4 1985-06-15 16:19:00.037648

# %%
funcionarios.dtypes
# Out:
# Nome Completo                 object
# Idade                        float64
# Renda Mensal                 float64
# Sexo                          object
# Cidade                        object
# Estado                        object
# Data de Nascimento    datetime64[ns]
# dtype: object

# %%
funcionarios = pd.read_csv(arquivo, names=colunas)
funcionarios.head()
# Out:
#              Nome  Idade         Renda       Sexo          Cidade  Estado  \
# 0   Nome Completo  Idade  Renda Mensal       Sexo          Cidade  Estado
# 1   João da Silva     54          2.27   Feminino       São Paulo      SP
# 2  Maria Oliveira     80         5.147  Masculino  Rio de Janeiro      RJ
# 3    Pedro Santos     46         8.657  Masculino  Belo Horizonte      MG
# 4       Ana Costa     30         5.026   Feminino        Salvador      BA
#
#                    Nascimento
# 0          Data de Nascimento
# 1  1970-06-15 22:19:00.037648
# 2  1944-06-15 10:19:00.037648
# 3  1978-06-15 22:19:00.037648
# 4  1994-06-15 22:19:00.037648

# %%
#importando ;

arquivo_pv = "dados/arquivo_csv_ponto_virgula.csv"
funcionarios_pv = pd.read_csv(arquivo_pv)
funcionarios_pv.head()
# Out:
#     Nome Completo  Idade  Renda Mensal       Sexo          Cidade Estado  \
# 0   João da Silva     54         2.270   Feminino       São Paulo     SP
# 1  Maria Oliveira     80         5.147  Masculino  Rio de Janeiro     RJ
# 2    Pedro Santos     46         8.657  Masculino  Belo Horizonte     MG
# 3       Ana Costa     30         5.026   Feminino        Salvador     BA
# 4   Lucas Pereira     39         4.128  Masculino        Curitiba     PR
#
#            Data de Nascimento
# 0  1970-06-15 22:19:00.037648
# 1  1944-06-15 10:19:00.037648
# 2  1978-06-15 22:19:00.037648
# 3  1994-06-15 22:19:00.037648
# 4  1985-06-15 16:19:00.037648

# %%
# importanto txt

arquivo_txt = "dados/arquivo_csv_ponto_pipe.txt"
funcionarios_txt = pd.read_csv(arquivo_txt, sep="|")
funcionarios_txt.head()
# Out:
#     Nome Completo  Idade  Renda Mensal       Sexo          Cidade Estado  \
# 0   João da Silva     54         2.270   Feminino       São Paulo     SP
# 1  Maria Oliveira     80         5.147  Masculino  Rio de Janeiro     RJ
# 2    Pedro Santos     46         8.657  Masculino  Belo Horizonte     MG
# 3       Ana Costa     30         5.026   Feminino        Salvador     BA
# 4   Lucas Pereira     39         4.128  Masculino        Curitiba     PR
#
#            Data de Nascimento
# 0  1970-06-15 22:19:00.037648
# 1  1944-06-15 10:19:00.037648
# 2  1978-06-15 22:19:00.037648
# 3  1994-06-15 22:19:00.037648
# 4  1985-06-15 16:19:00.037648

# %%
arquivo_vendas = "dados/vendas_2022.xlsx"
vendas = pd.read_excel(arquivo_vendas)
vendas
# Out:
#         Order Id      Product Id  Prod. Costs  Rent Costs  \
# 0       32899284  BL01-CA03-1101       637.11         0.0
# 1       32882015  BL01-CA03-1076       445.16         0.0
# 2       32961417  BL01-CA03-1076       445.16         0.0
# 3       33015853  BL01-CA03-1076       445.16         0.0
# 4       32981117  BL01-CA03-1040      2289.20         0.0
# ...          ...             ...          ...         ...
# 219978  32996994  BL02-CA01-2165       858.26         0.0
# 219979  33012973  BL02-CA01-2165      -429.13         0.0
# 219980  33014560  BL02-CA01-2165       623.90         0.0
# 219981  33015069  BL02-CA01-2165       520.25         0.0
# 219982  33068617  BL02-CA02-2179       550.00         0.0
#
#                  Sales Date  Fiscal Year  Total Cost  Customer Id  \
# 0       2022-02-09 00:00:00         2023      169.54         4564
# 1       2022-01-21 00:00:00         2023       95.84         4564
# 2       2022-05-20 00:00:00         2023       99.76         4564
# 3       2022-08-02 00:00:00         2023       99.76         4564
# 4       2022-06-21 00:00:00         2023       61.20         4564
# ...                     ...          ...         ...          ...
# 219978  2022-07-25 00:00:00         4046      600.60         3640
# 219979  2022-08-10 00:00:00         2023     -300.30         3640
# 219980  2022-08-24 00:00:00         2023      304.15         3640
# 219981  2022-08-29 00:00:00         2023      279.80         3640
# 219982  2022-11-02 00:00:00         2023      412.50         3640
#
#         Volume (LB)  Volume  ...                   City   Latitude  Longitude  \
# 0                 0       0  ...  São Bernardo Do Campo -23.698200 -46.621200
# 1              5290       0  ...  São Bernardo Do Campo -23.698200 -46.621200
# 2              5290       0  ...  São Bernardo Do Campo -23.698200 -46.621200
# 3              5290       0  ...  São Bernardo Do Campo -23.698200 -46.621200
# 4               480       0  ...  São Bernardo Do Campo -23.698200 -46.621200
# ...             ...     ...  ...                    ...        ...        ...
# 219978            0       0  ...          Nova Friburgo -22.317499 -42.565651
# 219979            0       0  ...          Nova Friburgo -22.317499 -42.565651
# 219980            0       0  ...          Nova Friburgo -22.317499 -42.565651
# 219981            0       0  ...          Nova Friburgo -22.317499 -42.565651
# 219982            0       0  ...          Nova Friburgo -22.317499 -42.565651
#
#            GEO ZONE Plant Name Plant State  Plant City Plant Latitude  \
# 0         Grande SP   Sorocaba          SP    Sorocaba     -23.433860
# 1         Grande SP   Sorocaba          SP    Sorocaba     -23.433860
# 2         Grande SP   Sorocaba          SP    Sorocaba     -23.433860
# 3         Grande SP   Sorocaba          SP    Sorocaba     -23.433860
# 4         Grande SP   Sorocaba          SP    Sorocaba     -23.433860
# ...             ...        ...         ...         ...            ...
# 219978  RJ Interior    Vitoria          ES  Porto Real     -22.440069
# 219979  RJ Interior    Vitoria          ES  Porto Real     -22.440069
# 219980  RJ Interior    Vitoria          ES  Porto Real     -22.440069
# 219981  RJ Interior    Vitoria          ES  Porto Real     -22.440069
# 219982  RJ Interior    Vitoria          ES  Porto Real     -22.440069
#
#        Plant Longitude   Plant Manager
# 0           -47.392490   Peter Stephen
# 1           -47.392490   Peter Stephen
# 2           -47.392490   Peter Stephen
# 3           -47.392490   Peter Stephen
# 4           -47.392490   Peter Stephen
# ...                ...             ...
# 219978      -44.317824  Alirio Cardoso
# 219979      -44.317824  Alirio Cardoso
# 219980      -44.317824  Alirio Cardoso
# 219981      -44.317824  Alirio Cardoso
# 219982      -44.317824  Alirio Cardoso
#
# [219983 rows x 34 columns]

# %%
vendas.itens()
